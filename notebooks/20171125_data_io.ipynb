# %%
# !/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Nov 25 10:00:00 2017

@author: droumis
"""

# %matplotlib inline
# %reload_ext autoreload
# %qtconsole
# %pdb

# %%
import loren_frank_data_processing as lfdp
from collections import namedtuple
# from tqdm import tqdm_notebook as tqdm

# %%
Animal = namedtuple('Animal', {'short_name', 'directory', 'preprocessing_directory'})
animals = {
    'JZ1': Animal(short_name='JZ1',
                  directory='../Raw-Data/JZ1',
                  preprocessing_directory='../Raw-Data/JZ1')}
date = (20161114)
epoch_index = ('JZ1', 1, 2)

# %%
full_tetrode_info = lfdp.make_tetrode_dataframe(animals)

# %%
full_tetrode_info.head()
# Out:
#                                 area  depth  nchans  numcells   ref subarea  \
# animal day epoch tetrode_number
# JZ1    1   1     1               mec      0       4         0  11.0       2
#                  2               mec      0       4         0  11.0       5
#                  3               mec      0       8         0  11.0       5
#                  4               mec      0       4         0  11.0       6
#                  5               sub      0       4         0  11.0       d
#
#                                 suparea animal  day  epoch  tetrode_number  \
# animal day epoch tetrode_number
# JZ1    1   1     1                  ctx    JZ1    1      1               1
#                  2                  ctx    JZ1    1      1               2
#                  3                  ctx    JZ1    1      1               3
#                  4                  ctx    JZ1    1      1               4
# ...

# %%
tetrode_info = full_tetrode_info.loc[epoch_index]

# %%
tetrode_info.head()
# Out:
#                area  depth  nchans  numcells   ref subarea suparea animal  \
# tetrode_number
# 1               mec      0       4         0  11.0       2     ctx    JZ1
# 2               mec      0       4         0  11.0       5     ctx    JZ1
# 3               mec      0       8         0  11.0       5     ctx    JZ1
# 4               mec      0       4         0  11.0       6     ctx    JZ1
# 5               sub      0       4         0  11.0       d     hpc    JZ1
#
#                 day  epoch  tetrode_number     tetrode_id
# tetrode_number
# 1                 1      2               1  JZ1_01_02_001
# 2                 1      2               2  JZ1_01_02_002
# 3                 1      2               3  JZ1_01_02_003
# 4                 1      2               4  JZ1_01_02_004
# 5                 1      2               5  JZ1_01_02_005

# %%
tetkey = ('JZ1', 1, 2, 21)

# %%
lfp_data = lfdp.get_LFP_dataframe(tetkey, animals)

# %%
lfp_data.shape
# Out:
# (1822589,)

# %%
position_data = lfdp.get_interpolated_position_dataframe(epoch_index, animals)

# %%
position_data.head()
# Out:
#                  labeled_segments from_well to_well task is_correct  \
# time
# 00:28:00.085200               1.0       NaN     NaN  NaN        NaN
# 00:28:00.085867               1.0       NaN     NaN  NaN        NaN
# 00:28:00.086534               1.0       NaN     NaN  NaN        NaN
# 00:28:00.087201               1.0       NaN     NaN  NaN        NaN
# 00:28:00.087868               1.0       NaN     NaN  NaN        NaN
#
#                  linear_distance  x_position  y_position  head_direction  \
# time
# 00:28:00.085200        42.908397   47.223078   51.476199       -3.077704
# 00:28:00.085867        42.908397   47.223078   51.476199       -3.077704
# 00:28:00.086534        42.908397   47.223078   51.476199       -3.077704
# 00:28:00.087201        42.908397   47.223078   51.476199       -3.077704
# 00:28:00.087868        42.908397   47.223078   51.476199       -3.077704
#
#                     speed
# time
# 00:28:00.085200  5.142901
# 00:28:00.085867  5.142901
# ...

# %%
position_data.plot()

# %%
position_data.plot.line('x_position','y_position')

# %%
interposition_data = lfdp.get_interpolated_position_dataframe(epoch_index, animals)

# %%
interposition_data.plot.line('x_position', 'y_position')

# %%
multiunit_data = lfdp.get_multiunit_indicator_dataframe(tetkey, animals)
#need to fix this.. output is empty

# %%
multiunit_data.head(-10)
# Out:
#                  channel_1_max  channel_2_max  channel_3_max  channel_4_max
# time
# 00:28:00.085200            NaN            NaN            NaN            NaN
# 00:28:00.085867            NaN            NaN            NaN            NaN
# 00:28:00.086534            NaN            NaN            NaN            NaN
# 00:28:00.087201            NaN            NaN            NaN            NaN
# 00:28:00.087868            NaN            NaN            NaN            NaN
# 00:28:00.088535            NaN            NaN            NaN            NaN
# 00:28:00.089202            NaN            NaN            NaN            NaN
# 00:28:00.089869            NaN            NaN            NaN            NaN
# 00:28:00.090536            NaN            NaN            NaN            NaN
# 00:28:00.091203            NaN            NaN            NaN            NaN
# 00:28:00.091870            NaN            NaN            NaN            NaN
# ...

# %%
multiunit_data.columns
# Out:
# Index(['channel_1_max', 'channel_2_max', 'channel_3_max', 'channel_4_max'], dtype='object')

# %%
ripcons_data = lfdp.get_computed_consensus_ripple_times(epoch_index, animals)
#need to fix this
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-7bdbd5017a45> in <module>()
# ----> 1 ripcons_data = lfdp.get_computed_consensus_ripple_times(epoch_index, animals)
#
# ~/anaconda3/envs/Roumis_2018/lib/python3.6/site-packages/loren_frank_data_processing/ripples.py in get_computed_consensus_ripple_times(epoch_key, animals)
#      94     animal, day, epoch = epoch_key
#      95     ripples_data = get_data_structure(
# ---> 96         animals[animal], day, 'candripples', 'candripples')
#      97     return list(map(tuple, ripples_data[epoch - 1]['riptimes'][0][0]))
#
# ~/anaconda3/envs/Roumis_2018/lib/python3.6/site-packages/loren_frank_data_processing/core.py in get_data_structure(animal, day, file_type, variable)
#     102     '''
#     103     try:
# --> 104         file = loadmat(get_data_filename(animal, day, file_type))
#     105     except IOError:
# ...
